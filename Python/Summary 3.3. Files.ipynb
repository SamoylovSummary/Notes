# %% [markdown]
# # Чтение и запись файлов

# %%
import os
tempDir = os.path.abspath('Temp')
if not os.path.exists(tempDir):
    os.mkdir(tempDir)
tempFile = os.path.join(tempDir, 'Temp.txt')
print(tempFile)
if not os.path.exists(tempFile):
    open(tempFile, 'w').write('Test string')
# Out:
# D:\Documents\Python\Notebook\Temp\Temp.txt

# %%
f = open(tempFile)
for line in f:
    print(line)
f.close()

print('=' * 100 )

with open(tempFile) as f:
    print(f.readline())
    print(f.read())
# Out:
# Методы объектов-файлов[править]
#
# В примерах ниже подразумевается, что заранее создан файловый объект с именем f.
#
# Чтобы прочитать содержимое файла, вызовите f.read(размер) — функция читает некоторое количество данных и возвращает их в виде строки или байтового объекта. размер — необязательный числовой параметр. Если размер опущен или отрицателен, будет прочитано и возвращено всё содержимое файла; если файл по величине в два раза больше оперативной памяти вашего компьютера, то решение этой проблемы остаётся на вашей совести. В противном случае, будет прочитано и возвращено максимум размер байт. Если был достигнут конец файла, f.read() вернёт пустую строку ().
# ...
# Методы объектов-файлов[править]
#
# В примерах ниже подразумевается, что заранее создан файловый объект с именем f.
# ...

# %%
import string
fileText = open(tempFile).read()
sorted(fileText.split(' '))
# Out:
# ['().',
#  'f.\nЧтобы',
#  'f.read()',
#  'f.read(размер)',
#  'В',
#  'Если',
#  'Если',
#  'Методы',
#  'байт.',
#  'байтового',
#  'больше',
#  'будет',
#  'будет',
#  'был',
#  'в',
#  'в',
#  'вашего',
#  'вашей',
#  'величине',
#  'вернёт',
#  'виде',
#  'возвращает',
#  'возвращено',
#  'возвращено',
#  'всё',
#  'вызовите',
#  'данных',
#  'два',
#  'достигнут',
#  'если',
#  'заранее',
#  'и',
#  'и',
#  'и',
#  'или',
#  'или',
#  'именем',
#  'их',
#  'количество',
#  'компьютера,',
#  'конец',
#  'максимум',
#  'на',
#  'некоторое',
#  'необязательный',
#  'ниже',
#  'объект',
#  'объекта.',
#  'объектов-файлов[править]\nВ',
#  'оперативной',
#  'опущен',
#  'остаётся',
#  'отрицателен,',
#  'памяти',
#  'параметр.',
#  'по',
#  'подразумевается,',
#  'примерах',
#  'проблемы',
#  'противном',
#  'прочитано',
#  'прочитано',
#  'прочитать',
#  'пустую',
#  'раза',
#  'размер',
#  'размер',
#  'размер',
#  'решение',
#  'с',
#  'случае,',
#  'совести.',
#  'содержимое',
# ...
